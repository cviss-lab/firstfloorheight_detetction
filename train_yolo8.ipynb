# %% [markdown]
# # Preparation

# %%
from google.colab import drive
drive.mount('/content/drive')
# !nvidia-smi
# Pip install method (recommended)
# !pip install ultralytics==8.0.20
from IPython import display
display.clear_output()
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# # Dowloading data and training

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet
# !pip install roboflow
from roboflow import Roboflow

#download data from roboflow
rf = Roboflow(api_key="CriILocIfdsxtkshBFzu")
project = rf.workspace("flood-4xb85").project("door_huaiyuan")
dataset = project.version(3).download("yolov8")

#training
# !yolo task=detect mode=train model= '/content/datasets/door_hy1gsv1-1/runs/detect/train2/weights/best.pt' data={dataset.location}/data.yaml epochs=150 imgsz=800 plots=True lr0=0.0001

# %%
#save
# !cp -r '/content/datasets/runs/detect' '/content/drive/MyDrive'
#avoid wasting computing resources
from google.colab import runtime
runtime.unassign()
